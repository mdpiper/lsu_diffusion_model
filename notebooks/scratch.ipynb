# %% [markdown]
# # Scratch

# %% [markdown]
# A notebook for exploring Python, Jupyter, etc.

# %%
D = 100
d = 50

# %%
D
# Out:
# 100

# %%
d
# Out:
# 50

# %%
whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# D          int     100
# d          int     50

# %%
import numpy as np

# %%
Lx = 8
dx = 0.5
x = np.arange(start=0, stop=Lx, step=dx)
nx = len(x)

# %%
nx
# Out:
# 16

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5])

# %%
x1 = np.linspace(start=0, stop=Lx, num=int(Lx/dx), endpoint=True)

# %%
x1
# Out:
# array([0.        , 0.53333333, 1.06666667, 1.6       , 2.13333333,
#        2.66666667, 3.2       , 3.73333333, 4.26666667, 4.8       ,
#        5.33333333, 5.86666667, 6.4       , 6.93333333, 7.46666667,
#        8.        ])

# %%
C = np.zeros_like(x)
C_left = 500
C_right = 0
C[x <= Lx//2] = C_left
C[x > Lx//2] = C_right

# %%
C
# Out:
# array([500., 500., 500., 500., 500., 500., 500., 500., 500.,   0.,   0.,
#          0.,   0.,   0.,   0.,   0.])

# %%
C[-1]
# Out:
# np.float64(0.0)

# %%
x[-1]
# Out:
# np.float64(7.5)

# %%
x[-2]
# Out:
# np.float64(7.0)

# %%
nx = len(x)
nx
# Out:
# 16

# %%
x[nx-1]
# Out:
# np.float64(7.5)

# %%
x[15]
# Out:
# np.float64(7.5)
